# %% [markdown]
# # MLP
#
# This file contains foundational implementations of artificial neural network. We will work through basic modules and algorithms step by step, implementing them from scratch. By the end, we'll use the modules we have implemented to train a network on the MNIST dataset.
#
# The modules are designed to mirror PyTorch's style, including support for autograd, forward passes, and related functionality.
#
# Note: we plan only to build basic modules in this file. Pytorch will be used otherwise.

# %% [markdown]
# ## MLP Architecture

# %%
import torch
